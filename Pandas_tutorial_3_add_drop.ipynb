# %% [markdown]
# # Pandas tutorial, part 2: adding and dropping

# %%
import pandas as pd

# %%
df = pd.read_csv('./datasets/titanic3.csv', dtype={'survived':bool, 'body':str})

# %%
df.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       1      True                    Allen, Miss. Elisabeth Walton  female
# 1       1      True                   Allison, Master. Hudson Trevor    male
# 2       1     False                     Allison, Miss. Helen Loraine  female
# 3       1     False             Allison, Mr. Hudson Joshua Creighton    male
# 4       1     False  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#      age  sibsp  parch  ticket      fare    cabin embarked boat body  \
# 0  29.00      0      0   24160  211.3375       B5        S    2  NaN
# 1   0.92      1      2  113781  151.5500  C22 C26        S   11  NaN
# 2   2.00      1      2  113781  151.5500  C22 C26        S  NaN  NaN
# 3  30.00      1      2  113781  151.5500  C22 C26        S  NaN  135
# 4  25.00      1      2  113781  151.5500  C22 C26        S  NaN  NaN
#
#                          home.dest
# 0                     St Louis, MO
# 1  Montreal, PQ / Chesterville, ON
# 2  Montreal, PQ / Chesterville, ON
# 3  Montreal, PQ / Chesterville, ON
# 4  Montreal, PQ / Chesterville, ON

# %% [markdown]
# ## 1. Drop columns and/or rows

# %%
df_1 = df.copy()
df_2 = df.copy()

# %% [markdown]
# ### 1.1. Drop columns ("`axis=1`")

# %% [markdown]
# Drop column(s) by name:

# %%
df_1.drop(['pclass','survived'], axis=1, inplace=True)
df_1.head()
# Out:
#                                               name     sex    age  sibsp  \
# 0                    Allen, Miss. Elisabeth Walton  female  29.00      0
# 1                   Allison, Master. Hudson Trevor    male   0.92      1
# 2                     Allison, Miss. Helen Loraine  female   2.00      1
# 3             Allison, Mr. Hudson Joshua Creighton    male  30.00      1
# 4  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female  25.00      1
#
#    parch  ticket      fare    cabin embarked boat body  \
# 0      0   24160  211.3375       B5        S    2  NaN
# 1      2  113781  151.5500  C22 C26        S   11  NaN
# 2      2  113781  151.5500  C22 C26        S  NaN  NaN
# 3      2  113781  151.5500  C22 C26        S  NaN  135
# 4      2  113781  151.5500  C22 C26        S  NaN  NaN
#
#                          home.dest
# 0                     St Louis, MO
# 1  Montreal, PQ / Chesterville, ON
# 2  Montreal, PQ / Chesterville, ON
# 3  Montreal, PQ / Chesterville, ON
# 4  Montreal, PQ / Chesterville, ON

# %% [markdown]
# Drop column(s) by integer location:

# %%
df_2.drop(df_2.columns[[0,1,4]], axis=1, inplace=True)
df_2.head()
# Out:
#                                               name     sex  sibsp  parch  \
# 0                    Allen, Miss. Elisabeth Walton  female      0      0
# 1                   Allison, Master. Hudson Trevor    male      1      2
# 2                     Allison, Miss. Helen Loraine  female      1      2
# 3             Allison, Mr. Hudson Joshua Creighton    male      1      2
# 4  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female      1      2
#
#    ticket      fare    cabin embarked boat body  \
# 0   24160  211.3375       B5        S    2  NaN
# 1  113781  151.5500  C22 C26        S   11  NaN
# 2  113781  151.5500  C22 C26        S  NaN  NaN
# 3  113781  151.5500  C22 C26        S  NaN  135
# 4  113781  151.5500  C22 C26        S  NaN  NaN
#
#                          home.dest
# 0                     St Louis, MO
# 1  Montreal, PQ / Chesterville, ON
# 2  Montreal, PQ / Chesterville, ON
# 3  Montreal, PQ / Chesterville, ON
# 4  Montreal, PQ / Chesterville, ON

# %% [markdown]
# ### 1.2. Drop rows ("`axis=2`")

# %%
df_3 = df.copy()
df_4 = df.copy()

# %% [markdown]
# Dropping rows by index name:

# %%
df_3.drop(3, axis=0, inplace=True)
df_3.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       1      True                    Allen, Miss. Elisabeth Walton  female
# 1       1      True                   Allison, Master. Hudson Trevor    male
# 2       1     False                     Allison, Miss. Helen Loraine  female
# 4       1     False  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
# 5       1      True                              Anderson, Mr. Harry    male
#
#      age  sibsp  parch  ticket      fare    cabin embarked boat body  \
# 0  29.00      0      0   24160  211.3375       B5        S    2  NaN
# 1   0.92      1      2  113781  151.5500  C22 C26        S   11  NaN
# 2   2.00      1      2  113781  151.5500  C22 C26        S  NaN  NaN
# 4  25.00      1      2  113781  151.5500  C22 C26        S  NaN  NaN
# 5  48.00      0      0   19952   26.5500      E12        S    3  NaN
#
#                          home.dest
# 0                     St Louis, MO
# 1  Montreal, PQ / Chesterville, ON
# 2  Montreal, PQ / Chesterville, ON
# 4  Montreal, PQ / Chesterville, ON
# 5                     New York, NY

# %% [markdown]
# Dropping rows by integer location:

# %%
df_4.drop(df_4.index[[0,2,5]], axis=0, inplace=True)
df_4.head()
# Out:
#    pclass  survived                                             name     sex  \
# 1       1      True                   Allison, Master. Hudson Trevor    male
# 3       1     False             Allison, Mr. Hudson Joshua Creighton    male
# 4       1     False  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
# 6       1      True                Andrews, Miss. Kornelia Theodosia  female
# 7       1     False                           Andrews, Mr. Thomas Jr    male
#
#      age  sibsp  parch  ticket      fare    cabin embarked boat body  \
# 1   0.92      1      2  113781  151.5500  C22 C26        S   11  NaN
# 3  30.00      1      2  113781  151.5500  C22 C26        S  NaN  135
# 4  25.00      1      2  113781  151.5500  C22 C26        S  NaN  NaN
# 6  63.00      1      0   13502   77.9583       D7        S   10  NaN
# 7  39.00      0      0  112050    0.0000      A36        S  NaN  NaN
#
#                          home.dest
# 1  Montreal, PQ / Chesterville, ON
# 3  Montreal, PQ / Chesterville, ON
# 4  Montreal, PQ / Chesterville, ON
# 6                       Hudson, NY
# 7                      Belfast, NI

# %% [markdown]
# ## 2. Append columns and/or rows

# %% [markdown]
# ### 2.1. Append columns (on the right): using "`.join()`" method

# %%
caller = pd.DataFrame({'key': ['K0', 'K1', 'K2', 'K3', 'K4', 'K5'],
                        'A': ['A0', 'A1', 'A2', 'A3', 'A4', 'A5']})
caller
# Out:
#     A key
# 0  A0  K0
# 1  A1  K1
# 2  A2  K2
# 3  A3  K3
# 4  A4  K4
# 5  A5  K5

# %%
other = pd.DataFrame({'key': ['K0', 'K1', 'K2'],
                       'B': ['B0', 'B1', 'B2']})
other
# Out:
#     B key
# 0  B0  K0
# 1  B1  K1
# 2  B2  K2

# %% [markdown]
# Join on index:

# %%
caller.join(other, lsuffix='_caller', rsuffix='_other')  # left join by default
# Out:
#     A key_caller    B key_other
# 0  A0         K0   B0        K0
# 1  A1         K1   B1        K1
# 2  A2         K2   B2        K2
# 3  A3         K3  NaN       NaN
# 4  A4         K4  NaN       NaN
# 5  A5         K5  NaN       NaN

# %% [markdown]
# Join on a specific column (need to set that column as index first):

# %%
caller.set_index('key').join(other.set_index('key'))
# Out:
#       A    B
# key
# K0   A0   B0
# K1   A1   B1
# K2   A2   B2
# K3   A3  NaN
# K4   A4  NaN
# K5   A5  NaN

# %% [markdown]
# ### 2.1. Append rows (at the bottom), using "`.append()`" method

# %%
jack = pd.Series([3,False,'Dawson, Mr. Jack','male',20,0,0,None,0,None,'S',None,None,None],
                 index=df.columns)

# %%
df.append(jack, ignore_index=True).tail()
# Out:
#       pclass  survived                       name     sex   age  sibsp  parch  \
# 1305       3     False      Zabour, Miss. Thamine  female   NaN      1      0
# 1306       3     False  Zakarian, Mr. Mapriededer    male  26.5      0      0
# 1307       3     False        Zakarian, Mr. Ortin    male  27.0      0      0
# 1308       3     False         Zimmerman, Mr. Leo    male  29.0      0      0
# 1309       3     False           Dawson, Mr. Jack    male  20.0      0      0
#
#       ticket     fare cabin embarked  boat  body home.dest
# 1305    2665  14.4542   NaN        C   NaN   NaN       NaN
# 1306    2656   7.2250   NaN        C   NaN   304       NaN
# 1307    2670   7.2250   NaN        C   NaN   NaN       NaN
# 1308  315082   7.8750   NaN        S   NaN   NaN       NaN
# 1309    None   0.0000  None        S  None  None      None

# %%
rose = pd.DataFrame([[1,True,'DeWitt Bukater, Miss. Rose','female',17,0,1,None,None,None,'S',None,None,None]],  # use [[...]]
                    columns=df.columns)

# %%
rose
# Out:
#    pclass  survived                        name     sex  age  sibsp  parch  \
# 0       1      True  DeWitt Bukater, Miss. Rose  female   17      0      1
#
#   ticket  fare cabin embarked  boat  body home.dest
# 0   None  None  None        S  None  None      None

# %%
df.append(rose, ignore_index=True).tail()  # "jack" not here, because append is not inplace
# Out:
#       pclass  survived                        name     sex   age  sibsp  \
# 1305       3     False       Zabour, Miss. Thamine  female   NaN      1
# 1306       3     False   Zakarian, Mr. Mapriededer    male  26.5      0
# 1307       3     False         Zakarian, Mr. Ortin    male  27.0      0
# 1308       3     False          Zimmerman, Mr. Leo    male  29.0      0
# 1309       1      True  DeWitt Bukater, Miss. Rose  female  17.0      0
#
#       parch  ticket     fare cabin embarked  boat  body home.dest
# 1305      0    2665  14.4542   NaN        C   NaN   NaN       NaN
# 1306      0    2656    7.225   NaN        C   NaN   304       NaN
# 1307      0    2670    7.225   NaN        C   NaN   NaN       NaN
# 1308      0  315082    7.875   NaN        S   NaN   NaN       NaN
# 1309      1    None     None  None        S  None  None      None

# %% [markdown]
# ## 3. Insert columns and/or rows

# %% [markdown]
# ### 3.1. Insert rows (at arbitrary location)

# %%
df.iloc[:2].append(jack, ignore_index=True).append(df.iloc[2:]).reset_index().head()
# Out:
#    index  pclass  survived                                  name     sex  \
# 0      0       1      True         Allen, Miss. Elisabeth Walton  female
# 1      1       1      True        Allison, Master. Hudson Trevor    male
# 2      2       3     False                      Dawson, Mr. Jack    male
# 3      2       1     False          Allison, Miss. Helen Loraine  female
# 4      3       1     False  Allison, Mr. Hudson Joshua Creighton    male
#
#      age  sibsp  parch  ticket      fare    cabin embarked  boat  body  \
# 0  29.00      0      0   24160  211.3375       B5        S     2   NaN
# 1   0.92      1      2  113781  151.5500  C22 C26        S    11   NaN
# 2  20.00      0      0    None    0.0000     None        S  None  None
# 3   2.00      1      2  113781  151.5500  C22 C26        S   NaN   NaN
# 4  30.00      1      2  113781  151.5500  C22 C26        S   NaN   135
#
#                          home.dest
# 0                     St Louis, MO
# 1  Montreal, PQ / Chesterville, ON
# 2                             None
# 3  Montreal, PQ / Chesterville, ON
# 4  Montreal, PQ / Chesterville, ON

# %% [markdown]
# ### 3.1. Insert columns (at arbitrary location)

# %%
is_children = df['age'] <= 18
df.insert(loc=df.columns.get_loc('age'), column='is_children', value=is_children)
df.iloc[:,:7].head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       1      True                    Allen, Miss. Elisabeth Walton  female
# 1       1      True                   Allison, Master. Hudson Trevor    male
# 2       1     False                     Allison, Miss. Helen Loraine  female
# 3       1     False             Allison, Mr. Hudson Joshua Creighton    male
# 4       1     False  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#    is_children    age  sibsp
# 0        False  29.00      0
# 1         True   0.92      1
# 2         True   2.00      1
# 3        False  30.00      1
# 4        False  25.00      1
