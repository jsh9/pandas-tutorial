# %% [markdown]
# # Pandas tutorial, part 2: boolean indexing

# %%
import pandas as pd

# %%
df = pd.read_csv('./datasets/titanic3.csv', dtype={'survived':bool, 'body':str})
df.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       1      True                    Allen, Miss. Elisabeth Walton  female
# 1       1      True                   Allison, Master. Hudson Trevor    male
# 2       1     False                     Allison, Miss. Helen Loraine  female
# 3       1     False             Allison, Mr. Hudson Joshua Creighton    male
# 4       1     False  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#      age  sibsp  parch  ticket      fare    cabin embarked boat body  \
# 0  29.00      0      0   24160  211.3375       B5        S    2  NaN
# 1   0.92      1      2  113781  151.5500  C22 C26        S   11  NaN
# 2   2.00      1      2  113781  151.5500  C22 C26        S  NaN  NaN
# 3  30.00      1      2  113781  151.5500  C22 C26        S  NaN  135
# 4  25.00      1      2  113781  151.5500  C22 C26        S  NaN  NaN
#
#                          home.dest
# 0                     St Louis, MO
# 1  Montreal, PQ / Chesterville, ON
# 2  Montreal, PQ / Chesterville, ON
# 3  Montreal, PQ / Chesterville, ON
# 4  Montreal, PQ / Chesterville, ON

# %% [markdown]
# ## 1. Viewing data

# %% [markdown]
# See survived infants:

# %%
df[(df['survived'] == True) & (df['age'] < 1)]  # other operatorsinclude "|" and "~"
# Out:
#       pclass  survived                                     name     sex   age  \
# 1          1      True           Allison, Master. Hudson Trevor    male  0.92
# 359        2      True            Caldwell, Master. Alden Gates    male  0.83
# 427        2      True                Hamalainen, Master. Viljo    male  0.67
# 548        2      True          Richards, Master. George Sibley    male  0.83
# 590        2      True                    West, Miss. Barbara J  female  0.92
# 611        3      True                Aks, Master. Philip Frank    male  0.83
# 657        3      True                   Baclini, Miss. Eugenie  female  0.75
# 658        3      True            Baclini, Miss. Helene Barbara  female  0.75
# 763        3      True  Dean, Miss. Elizabeth Gladys "Millvina"  female  0.17
# 1240       3      True          Thomas, Master. Assad Alexander    male  0.42
#
#       sibsp  parch      ticket      fare    cabin embarked boat body  \
# 1         1      2      113781  151.5500  C22 C26        S   11  NaN
# 359       0      2      248738   29.0000      NaN        S   13  NaN
# 427       1      1      250649   14.5000      NaN        S    4  NaN
# 548       1      1       29106   18.7500      NaN        S    4  NaN
# 590       1      2  C.A. 34651   27.7500      NaN        S   10  NaN
# 611       0      1      392091    9.3500      NaN        S   11  NaN
# 657       2      1        2666   19.2583      NaN        C    C  NaN
# 658       2      1        2666   19.2583      NaN        C    C  NaN
# 763       1      2   C.A. 2315   20.5750      NaN        S   10  NaN
# 1240      0      1        2625    8.5167      NaN        C   16  NaN
#
#                               home.dest
# 1       Montreal, PQ / Chesterville, ON
# 359   Bangkok, Thailand / Roseville, IL
# 427                         Detroit, MI
# 548                Cornwall / Akron, OH
# 590                 Bournmouth, England
# 611         London, England Norfolk, VA
# 657                  Syria New York, NY
# 658                  Syria New York, NY
# 763          Devon, England Wichita, KS
# 1240                                NaN

# %% [markdown]
# Check passenger with last name "Smith":

# %%
criterion = df['name'].map(lambda x: x.startswith('Smith'))
criterion.head()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# Name: name, dtype: bool

# %%
df[criterion]
# Out:
#       pclass  survived                                            name  \
# 267        1     False                         Smith, Mr. James Clinch
# 268        1     False                        Smith, Mr. Lucien Philip
# 269        1     False                      Smith, Mr. Richard William
# 270        1      True  Smith, Mrs. Lucien Philip (Mary Eloise Hughes)
# 564        2      True                       Smith, Miss. Marion Elsie
# 1215       3     False                               Smith, Mr. Thomas
#
#          sex   age  sibsp  parch  ticket     fare cabin embarked boat body  \
# 267     male  56.0      0      0   17764  30.6958    A7        C  NaN  NaN
# 268     male  24.0      1      0   13695  60.0000   C31        S  NaN  NaN
# 269     male   NaN      0      0  113056  26.0000   A19        S  NaN  NaN
# 270   female  18.0      1      0   13695  60.0000   C31        S    6  NaN
# 564   female  40.0      0      0   31418  13.0000   NaN        S    9  NaN
# 1215    male   NaN      0      0  384461   7.7500   NaN        Q  NaN  NaN
#
#                       home.dest
# 267   St James, Long Island, NY
# 268              Huntington, WV
# 269           Streatham, Surrey
# 270              Huntington, WV
# 564                         NaN
# 1215                        NaN

# %%
df[criterion & ~(df['age'] >= 30)]
# Out:
#       pclass  survived                                            name  \
# 268        1     False                        Smith, Mr. Lucien Philip
# 269        1     False                      Smith, Mr. Richard William
# 270        1      True  Smith, Mrs. Lucien Philip (Mary Eloise Hughes)
# 1215       3     False                               Smith, Mr. Thomas
#
#          sex   age  sibsp  parch  ticket   fare cabin embarked boat body  \
# 268     male  24.0      1      0   13695  60.00   C31        S  NaN  NaN
# 269     male   NaN      0      0  113056  26.00   A19        S  NaN  NaN
# 270   female  18.0      1      0   13695  60.00   C31        S    6  NaN
# 1215    male   NaN      0      0  384461   7.75   NaN        Q  NaN  NaN
#
#               home.dest
# 268      Huntington, WV
# 269   Streatham, Surrey
# 270      Huntington, WV
# 1215                NaN

# %% [markdown]
# ## 2. Conditional value setting

# %% [markdown]
# Replace fare of every Smith to -9999:

# %%
df.loc[criterion, 'fare'] = -9999

# %%
df[criterion]
# Out:
#       pclass  survived                                            name  \
# 267        1     False                         Smith, Mr. James Clinch
# 268        1     False                        Smith, Mr. Lucien Philip
# 269        1     False                      Smith, Mr. Richard William
# 270        1      True  Smith, Mrs. Lucien Philip (Mary Eloise Hughes)
# 564        2      True                       Smith, Miss. Marion Elsie
# 1215       3     False                               Smith, Mr. Thomas
#
#          sex   age  sibsp  parch  ticket    fare cabin embarked boat body  \
# 267     male  56.0      0      0   17764 -9999.0    A7        C  NaN  NaN
# 268     male  24.0      1      0   13695 -9999.0   C31        S  NaN  NaN
# 269     male   NaN      0      0  113056 -9999.0   A19        S  NaN  NaN
# 270   female  18.0      1      0   13695 -9999.0   C31        S    6  NaN
# 564   female  40.0      0      0   31418 -9999.0   NaN        S    9  NaN
# 1215    male   NaN      0      0  384461 -9999.0   NaN        Q  NaN  NaN
#
#                       home.dest
# 267   St James, Long Island, NY
# 268              Huntington, WV
# 269           Streatham, Surrey
# 270              Huntington, WV
# 564                         NaN
# 1215                        NaN
